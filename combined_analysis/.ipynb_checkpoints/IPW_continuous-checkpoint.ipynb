# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy import stats

# %%
# test on mesa data

mesa_raw = pd.read_csv('../data_processed/MESA/Y_BaselineX_raw_full.csv', index_col=False)
mesa_raw = mesa_raw.dropna()

analysis_feature = ['Y_10y','nSES','nFavFood','nPhysFac', 'nRS', 
                    'FamIncome', 'nutrition', 'PhysAct', 'currentSmoker', 'alc',
                    'age', 'race','gender', 'Diabetes', 'hdl', 'totchol', 'sbp']

mesa_raw = mesa_raw[analysis_feature]

data = mesa_raw.copy()

data.head()
# Out:
#    Y_10y      nSES  nFavFood  nPhysFac       nRS  FamIncome  nutrition  \
# 2      0  0.859551  0.318447  0.000000  2.882767        4.0        0.0
# 3      0  0.545351  0.955342  0.636895  0.197152       11.0        0.0
# 4      0 -1.412698  0.955342  1.910684 -1.743838        6.0        0.0
# 5      0 -0.450402  0.000000  0.318447 -1.424273       11.0        1.0
# 8      0  0.955388  0.636895  0.636895  4.744247        6.0        1.0
#
#    PhysAct  currentSmoker  alc   age  race  gender  Diabetes   hdl  totchol  \
# 2      2.0            1.0  0.0  78.0   3.0     0.0       0.0  38.0    198.0
# 3      2.0            0.0  0.0  60.0   3.0     1.0       1.0  36.0    179.0
# 4      1.0            1.0  0.0  70.0   3.0     0.0       0.0  57.0    236.0
# 5      2.0            0.0  0.0  62.0   3.0     0.0       0.0  50.0    174.0
# 8      1.0            1.0  0.0  53.0   3.0     0.0       0.0  59.0    215.0
#
#      sbp
# 2  149.5
# 3  141.5
# 4  145.5
# 5  164.5
# 8  133.0

# %%
data['nSES'].plot.kde()

plt.title('Density Plot for nSES')
plt.xlabel('nSES Values')
plt.ylabel('Density')

# Display the plot
plt.show()

# %%
# Step 1: estimate propensity density

def conditional_densities(data, use_confounders=True):
    formula = "nSES ~ 1" 
    if use_confounders:
        formula += """ + 
        nFavFood + nPhysFac + nRS+
        FamIncome+C(nutrition)+C(PhysAct)+C(currentSmoker)+C(alc)+
        age + sbp + hdl + totchol + C(Diabetes) + C(race)
        """
    model = sm.formula.ols(formula, data=data).fit()
    density = stats.norm( 
        loc=model.fittedvalues,
        scale=model.resid.std(),
    )  # a series of distributions?
    densities = density.pdf(data["nSES"])
    densities = pd.Series(densities, index=model.fittedvalues.index)
    return densities

# %%
denominator = conditional_densities(data, use_confounders=True)
numerator = conditional_densities(data, use_confounders=False)
# weight
generalized_ipw = numerator / denominator


# Step 2: Weighted Least Squares (WLS) regression 
msm = sm.formula.wls(  # Using GEE instead will lead to better (more conservative) uncertainty intervals
    "Y_10y ~ 1 + nSES + I(nSES**2) + I(nSES**3)",
    data=data,
    weights=generalized_ipw,
).fit()

dosage = list(range(-10,10))  # hypothesized dosage value for plotting
dosage = pd.DataFrame(
    data={"nSES": dosage, "I(nSES**2)": [d**2 for d in dosage], 
         "I(nSES**3)": [d**3 for d in dosage]},
    index=dosage,
)
response = msm.predict(dosage)
ax = response.plot(
    kind="line",
    xlabel="nSES value",
    ylabel="Change in 10-year CVD risk"
)

# %%
msm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                  Y_10y   R-squared:                       0.000
# Model:                            WLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                     0.000
# Date:                Sat, 17 Feb 2024   Prob (F-statistic):               1.00
# Time:                        16:14:41   Log-Likelihood:                -73887.
# No. Observations:                4619   AIC:                         1.478e+05
# Df Residuals:                    4616   BIC:                         1.478e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     1.364e-207  4.99e-106  2.73e-102      1.000  -9.79e-106   9.79e-106
# nSES          3.958e-207  1.45e-105  2.73e-102      1.000  -2.84e-105   2.84e-105
# I(nSES ** 2)  1.462e-208  5.35e-107  2.73e-102      1.000  -1.05e-106   1.05e-106
# I(nSES ** 3) -3.144e-207  1.15e-105 -2.73e-102      1.000  -2.26e-105   2.26e-105
# ==============================================================================
# Omnibus:                    16253.353   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4100798623.916
# Skew:                          67.941   Prob(JB):                         0.00
# Kurtosis:                    4617.000   Cond. No.                     2.09e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
formula = "Y_10y ~ 1 + nSES + nFavFood + nPhysFac + nRS + \
        FamIncome+C(nutrition)+C(PhysAct)+C(currentSmoker)+C(alc)+ \
        age + sbp + hdl + totchol + C(Diabetes) + C(race)"

test_model = sm.formula.ols(formula, data=data).fit()
test_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Y_10y   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     14.53
# Date:                Sat, 17 Feb 2024   Prob (F-statistic):           3.21e-48
# Time:                        16:12:36   Log-Likelihood:                -645.00
# No. Observations:                4619   AIC:                             1332.
# Df Residuals:                    4598   BIC:                             1467.
# Df Model:                          20
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -0.2770      0.048     -5.741      0.000      -0.372      -0.182
# C(nutrition)[T.1.0]        -0.0198      0.009     -2.265      0.024      -0.037      -0.003
# C(nutrition)[T.2.0]        -0.0949      0.070     -1.353      0.176      -0.232       0.043
# C(PhysAct)[T.1.0]           0.0059      0.013      0.439      0.660      -0.021       0.032
# C(PhysAct)[T.2.0]          -0.0074      0.011     -0.687      0.492      -0.029       0.014
# C(currentSmoker)[T.1.0]     0.0031      0.009      0.351      0.725      -0.014       0.021
# C(currentSmoker)[T.2.0]     0.0438      0.013      3.338      0.001       0.018       0.069
# C(alc)[T.1.0]              -0.0010      0.010     -0.103      0.918      -0.020       0.018
# C(Diabetes)[T.1.0]          0.0650      0.014      4.602      0.000       0.037       0.093
# C(race)[T.2.0]             -0.0374      0.017     -2.182      0.029      -0.071      -0.004
# C(race)[T.3.0]             -0.0411      0.013     -3.190      0.001      -0.066      -0.016
# C(race)[T.4.0]             -0.0177      0.013     -1.391      0.164      -0.043       0.007
# nSES                        0.0070      0.004      1.684      0.092      -0.001       0.015
# nFavFood                   -0.0021      0.002     -1.289      0.198      -0.005       0.001
# nPhysFac                    0.0017      0.001      1.801      0.072      -0.000       0.004
# nRS                         0.0029      0.002      1.309      0.190      -0.001       0.007
# FamIncome                  -0.0015      0.001     -1.024      0.306      -0.004       0.001
# age                         0.0043      0.000      9.301      0.000       0.003       0.005
# sbp                         0.0011      0.000      5.180      0.000       0.001       0.002
# hdl                        -0.0015      0.000     -5.118      0.000      -0.002      -0.001
# totchol                     0.0003      0.000      2.785      0.005    9.95e-05       0.001
# ==============================================================================
# Omnibus:                     2351.659   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10738.654
# Skew:                           2.592   Prob(JB):                         0.00
# Kurtosis:                       8.379   Cond. No.                     4.21e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.21e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
